# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
G_losses = np.load('logs/Jun18/G80_D20_WI0/loss_g.npy')
D_losses = np.load("logs/Jun18/G80_D20_WI0/loss_d.npy")
# d_losses
# Out:
# array([2.15723181, 3.30177689, 2.86841917, ..., 0.65101862, 0.65095156,
#        0.65285075])

# %%
plt.figure(figsize=(10,5))
plt.title(f"Generator and Discriminator Loss During Training. D: {80}M,  G: {6}M")
plt.plot(np.arange(len(G_losses)), G_losses ,label="G")
# plt.plot(np.arange(len(D_losses)), D_losses,label="D")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
